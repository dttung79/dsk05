# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.models import Sequential
# Out:
# /Users/tungdt/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
X = np.linspace(0, 10, 100)
Y = 2.5 * X + 1 + np.random.normal(0, 2, 100)
plt.figure(figsize=(8, 6))
plt.scatter(X, Y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter plot of X vs Y')
plt.grid()
plt.show()

# %%
model = Sequential([
    Dense(1, input_shape=(1,), activation=None)  # No activation for linear regression
])

model.compile(optimizer='sgd', loss='mean_squared_error')

# train model
model.fit(X, Y, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 201.0408
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5632
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5252
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9590
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6199
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1115
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8836
# Epoch 8/100
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8670
# /Users/tungdt/Library/Python/3.9/lib/python/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5317
# Epoch 9/100
# ...

# %%
loss_values = model.history.history['loss']
plt.figure(figsize=(8, 6))
plt.plot(loss_values)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.grid()
plt.show()

# %%
Y_pred = model.predict(X)
plt.figure(figsize=(8, 6))
plt.scatter(X, Y, label='Data', color='blue')
plt.scatter(X, Y_pred, label='Model Prediction', color='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter plot of X vs Y with Model Prediction')
plt.legend()
plt.grid()
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
weights, biases = model.layers[0].get_weights()
print("Weights:\n", weights)
print("Biases:\n", biases)
# Out:
# Weights:
#  [[2.3302212]]
# Biases:
#  [0.86804867]

# %%
model = Sequential([
    Dense(30, input_shape=(1, ), activation='tanh'),
    Dense(30, activation='tanh'),
    Dense(1, activation=None)   # Output layer for regression
])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')
model.fit(X, Y, epochs=100, verbose=0)

loss_values = model.history.history['loss']
plt.figure(figsize=(8, 6))
plt.plot(loss_values)
plt.xlabel('Epoch') 
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs for Deep NN')
plt.grid()
plt.show()

# %%
Y_pred = model.predict(X)
plt.figure(figsize=(8, 6))
plt.scatter(X, Y, label='Data', color='blue')
plt.scatter(X, Y_pred, label='Model Prediction', color='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter plot of X vs Y with Deep NN Model Prediction')
plt.legend()
plt.grid()
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
X = np.linspace(-20, 20, 500)
Y = 2.0 * X ** 2 - 3.0 * X + 5.0 + np.random.normal(0, 20, 500)
plt.figure(figsize=(8, 6))
plt.scatter(X, Y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter plot of X vs Y (Quadratic Data)')
plt.grid()
plt.show()

# %%
Y = (Y - np.min(Y)) / (np.max(Y) - np.min(Y))
plt.figure(figsize=(8, 6))
plt.scatter(X, Y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter plot of X vs Y (Quadratic Data)')
plt.grid()
plt.show()

# %%
model = Sequential([
    Dense(50, input_shape=(1, ), activation='tanh'),
    Dense(50, activation='relu'),
    Dense(50, activation='tanh'),
    Dense(1, activation='tanh')   # Output layer for regression
])
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X, Y, epochs=100, verbose=0)

loss_values = model.history.history['loss']
plt.figure(figsize=(8, 6))
plt.plot(loss_values)
plt.xlabel('Epoch') 
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs for Deep NN')
plt.grid()
plt.show()

# %%
Y_pred = model.predict(X)
plt.figure(figsize=(8, 6))
plt.scatter(X, Y, label='Data', color='blue')
plt.scatter(X, Y_pred, label='Model Prediction', color='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter plot of X vs Y with Deep NN Model Prediction')
plt.legend()
plt.grid()
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x35d61a160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# Đưa Y_pred từ [0, 1] về lại scale gốc của Y
Y = 2.0 * X ** 2 - 3.0 * X + 5.0 + np.random.normal(0, 20, 500)
Y_pred_scale_upd = Y_pred * (np.max(Y) - np.min(Y)) + np.min(Y)
plt.figure(figsize=(8, 6))


plt.scatter(X, Y, label='Data', color='blue')
plt.scatter(X, Y_pred_scale_upd, label='Model Prediction', color='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter plot of X vs Y with Deep NN Model Prediction (Scaled Back)')
plt.legend()
plt.grid()
plt.show()
