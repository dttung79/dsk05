# %% [markdown]
# # Bài Tập Thực Hành Dự Đoán Giá Nhà

# %% [markdown]
# ## Giới Thiệu
#
# Trong bài thực hành trước, chúng ta sẽ ứng dụng mô hình hồi quy tuyến tính đa biến bằng phương pháp OLS để tiến hành dự đoán giá nhà trong bộ dữ liệu được cho. Tuy vậy, các yếu tố ảnh hưởng đến giá nhà có tính chất phức tạp hơn so với những gì mô hình hồi quy tuyến tính có thể biểu đạt. Vì vậy, hôm nay chúng ta sẽ xây dựng một Neural Network để dự đoán giá nhà ở.
#
# Mục tiêu của bài toán này chính là để xây dựng một mô hình với tính năng dự đoán giá thị trường của các chủ nhà đang cân nhắc rao bán căn nhà của mình. Đối với bài toán này, các bạn sẽ được tự do thực hiện bài làm mà không cần phải tuân theo bất kỳ chỉ dẫn nào. Bài tập này sẽ được thực hiện dưới dạng một cuộc thi xem liệu ai là người sở hữu mô hình với dự đoán chính xác nhất. Các dự đoán sẽ được đánh giá trên tiêu chí `RMSE` để tìm ra được người sở hữu mô hình dự đoán chính xác nhất.
#
# Về dữ liệu, chúng ta sẽ sử dụng bộ dữ liệu Ames Housing Dataset được tổng hợp bởi Dean De Cock về đặc tính và giá trị của các ngôi nhà tại bang Iowa ở Mỹ, gồm 3 file chính như sau:
# * [**Bộ dữ liệu Train**](https://drive.google.com/file/d/1smQLHUt-L3M2uEmBRgmWC0E9EE-RGw4A/view?usp=drive_link)
# * [**Bộ dữ liệu Evaluation**](https://drive.google.com/file/d/1TTg-MOFtIM3yVJANacYSNMYRfbETTMCn/view?usp=drive_link)
# * [**Tài liệu mô tả dữ liệu (Data Dictionary)**](https://drive.google.com/drive/folders/1a17hadX2u8ELZcSwb1ac4Ubhl66paymT?usp=drive_link)

# %% [markdown]
# ## Bước 1: Khám Phá Bộ Dữ Liệu Nội Bộ Của Công Ty
#
# Hãy thực hiện EDA để khám phá và xử lý bộ dữ liệu

# %%
### CODE CỦA BẠN ##

# %% [markdown]
# ## Bước 2: Xây Dựng Mô Hình Bằng Bộ Dữ Liệu Train
# Hãy xây dựng một mô hình từ bộ dữ liệu nội bộ của công ty. Hãy tự do thực hiện điều chỉnh các số lượng và đặc tính layer cũng như thực hiện hyperparameter tuning để đạt được dự đoán tốt nhất

# %%
### CODE CỦA BẠN ###

# %% [markdown]
# ## Bước 3: Đánh Giá Mô Hình Bằng Bộ Dữ Liệu Evaluation
#
# Hãy tiến hành đưa bộ dữ liệu thứ hai vào mô hình để tiến hành dự đoán, sau đó so sánh với giá cả thực tế của các ngôi nhà sau khi được bán đi trên tiêu chí `RMSE`. Hãy tìm cách sao cho `RMSE` càng tối ưu càng tốt

# %%
### CODE CỦA BẠN ###

# %% [markdown]
# ## Bước 4: Hoàn Thiện Mô Hình Và Nộp Bài

# %% [markdown]
# Sau khi hoàn thành bài thực hành, các anh chị hãy tiến hành nộp bài
